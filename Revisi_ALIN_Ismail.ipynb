# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

img_path = 'Ismail_.jpeg'
img = cv2.imread(img_path)
print(img.shape)

plt.imshow(img)

fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

R, G, B = fix_img[:,:,0], fix_img[:,:,1], fix_img[:,:,2]
print (np.array(fix_img))
# Out:
# (4000, 1847, 3)
# [[[35 39 42]
#   [36 40 43]
#   [37 38 42]
#   ...
#   [38 38 38]
#   [39 39 39]
#   [37 37 37]]
#
#  [[36 40 43]
#   [37 41 44]
#   [37 38 42]
#   ...
#   [38 38 38]
#   [38 38 38]
#   [38 38 38]]
#
#  [[35 39 42]
#   [36 40 43]
#   [34 38 41]
#   ...
#   [38 38 38]
#   [41 41 41]
#   [37 37 37]]
#
#  ...
#
#  [[23 34 17]
#   [22 30 17]
#   [24 26 21]
#   ...
#   [39 32 26]
#   [35 28 22]
#   [37 30 24]]
#
#  [[36 57 16]
#   [27 44 12]
#   [21 29 16]
#   ...
#   [38 31 23]
#   [37 30 22]
#   [39 32 26]]
#
#  [[37 64 11]
#   [23 44  3]
#   [19 30 13]
#   ...
#   [36 29 21]
#   [38 31 23]
#   [36 29 23]]]

# %%
fix_img[:] = np.max(fix_img, axis = -1, keepdims = 1)/2 + np.min(fix_img, axis = -1, keepdims = 1)/2
print(np.array(fix_img[:]))

plt.axis('off')
plt.imshow(fix_img[:])
plt.savefig('Mode Lightness.jpg', bbox_inches='tight')
# Out:
# [[[38 38 38]
#   [39 39 39]
#   [39 39 39]
#   ...
#   [38 38 38]
#   [39 39 39]
#   [37 37 37]]
#
#  [[39 39 39]
#   [40 40 40]
#   [39 39 39]
#   ...
#   [38 38 38]
#   [38 38 38]
#   [38 38 38]]
#
#  [[38 38 38]
#   [39 39 39]
#   [37 37 37]
#   ...
#   [38 38 38]
#   [41 41 41]
#   [37 37 37]]
#
#  ...
#
#  [[25 25 25]
#   [23 23 23]
#   [23 23 23]
#   ...
#   [32 32 32]
#   [28 28 28]
#   [30 30 30]]
#
#  [[36 36 36]
#   [28 28 28]
#   [22 22 22]
#   ...
#   [30 30 30]
#   [29 29 29]
#   [32 32 32]]
#
#  [[37 37 37]
#   [23 23 23]
#   [21 21 21]
#   ...
#   [28 28 28]
#   [30 30 30]
#   [29 29 29]]]

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

img_path = 'Ismail_.jpeg'
img = cv2.imread(img_path)
print(img.shape)

plt.imshow(img)

fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

R, G, B = fix_img[:,:,0], fix_img[:,:,1], fix_img[:,:,2]
print (np.array(fix_img))
# Out:
# (4000, 1847, 3)
# [[[35 39 42]
#   [36 40 43]
#   [37 38 42]
#   ...
#   [38 38 38]
#   [39 39 39]
#   [37 37 37]]
#
#  [[36 40 43]
#   [37 41 44]
#   [37 38 42]
#   ...
#   [38 38 38]
#   [38 38 38]
#   [38 38 38]]
#
#  [[35 39 42]
#   [36 40 43]
#   [34 38 41]
#   ...
#   [38 38 38]
#   [41 41 41]
#   [37 37 37]]
#
#  ...
#
#  [[23 34 17]
#   [22 30 17]
#   [24 26 21]
#   ...
#   [39 32 26]
#   [35 28 22]
#   [37 30 24]]
#
#  [[36 57 16]
#   [27 44 12]
#   [21 29 16]
#   ...
#   [38 31 23]
#   [37 30 22]
#   [39 32 26]]
#
#  [[37 64 11]
#   [23 44  3]
#   [19 30 13]
#   ...
#   [36 29 21]
#   [38 31 23]
#   [36 29 23]]]

# %%
gray_img = np.mean(fix_img, axis = -1)
print(np.array(gray_img))

plt.axis('off')
plt.imshow(gray_img, cmap='gray')
plt.savefig('Metode Average.jpg' , bbox_inches='tight')
# Out:
# [[38.66666667 39.66666667 39.         ... 38.         39.
#   37.        ]
#  [39.66666667 40.66666667 39.         ... 38.         38.
#   38.        ]
#  [38.66666667 39.66666667 37.66666667 ... 38.         41.
#   37.        ]
#  ...
#  [24.66666667 23.         23.66666667 ... 32.33333333 28.33333333
#   30.33333333]
#  [36.33333333 27.66666667 22.         ... 30.66666667 29.66666667
#   32.33333333]
#  [37.33333333 23.33333333 20.66666667 ... 28.66666667 30.66666667
#   29.33333333]]

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

img_path = 'Ismail_.jpeg'
img = cv2.imread(img_path)
print(img.shape)

plt.imshow(img)

fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

R, G, B = fix_img[:,:,0], fix_img[:,:,1], fix_img[:,:,2]
print (np.array(fix_img))

lumi_img = (0.2126*R) + (0.7152*G) + (0.0722*B)
print(lumi_img)

plt.axis('off')
plt.imshow(lumi_img, cmap = 'gray')
plt.savefig('Metode Luminosity.jpg' , bbox_inches='tight')
# Out:
# (4000, 1847, 3)
# [[[35 39 42]
#   [36 40 43]
#   [37 38 42]
#   ...
#   [38 38 38]
#   [39 39 39]
#   [37 37 37]]
#
#  [[36 40 43]
#   [37 41 44]
#   [37 38 42]
#   ...
#   [38 38 38]
#   [38 38 38]
#   [38 38 38]]
#
#  [[35 39 42]
#   [36 40 43]
#   [34 38 41]
#   ...
#   [38 38 38]
#   [41 41 41]
#   [37 37 37]]
#
#  ...
#
#  [[23 34 17]
#   [22 30 17]
#   [24 26 21]
#   ...
#   [39 32 26]
#   [35 28 22]
#   [37 30 24]]
#
#  [[36 57 16]
#   [27 44 12]
#   [21 29 16]
#   ...
#   [38 31 23]
#   [37 30 22]
#   [39 32 26]]
#
#  [[37 64 11]
#   [23 44  3]
#   [19 30 13]
#   ...
#   [36 29 21]
#   [38 31 23]
#   [36 29 23]]]
# [[38.3662 39.3662 38.0762 ... 38.     39.     37.    ]
#  [39.3662 40.3662 38.0762 ... 38.     38.     38.    ]
#  [38.3662 39.3662 37.3662 ... 38.     41.     37.    ]
#  ...
#  [30.434  27.3606 25.2138 ... 33.055  29.055  31.055 ]
#  [49.5752 38.0754 26.3606 ... 31.9106 30.9106 33.055 ]
#  [54.4332 36.5752 26.434  ... 29.9106 31.9106 30.055 ]]

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

img_path = 'Ismail_.jpeg'
img = cv2.imread(img_path)
print(img.shape)

plt.imshow(img)

fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

R, G, B = fix_img[:,:,0], fix_img[:,:,1], fix_img[:,:,2]
print (np.array(fix_img))

warv_img = (0.299*R) + (0.587*G) + (0.114*B)
print(warv_img)

plt.axis('off')
plt.imshow(warv_img, cmap = 'gray')
plt.savefig('Metode Weighted Average.jpg' , bbox_inches='tight')
# Out:
# (4000, 1847, 3)
# [[[35 39 42]
#   [36 40 43]
#   [37 38 42]
#   ...
#   [38 38 38]
#   [39 39 39]
#   [37 37 37]]
#
#  [[36 40 43]
#   [37 41 44]
#   [37 38 42]
#   ...
#   [38 38 38]
#   [38 38 38]
#   [38 38 38]]
#
#  [[35 39 42]
#   [36 40 43]
#   [34 38 41]
#   ...
#   [38 38 38]
#   [41 41 41]
#   [37 37 37]]
#
#  ...
#
#  [[23 34 17]
#   [22 30 17]
#   [24 26 21]
#   ...
#   [39 32 26]
#   [35 28 22]
#   [37 30 24]]
#
#  [[36 57 16]
#   [27 44 12]
#   [21 29 16]
#   ...
#   [38 31 23]
#   [37 30 22]
#   [39 32 26]]
#
#  [[37 64 11]
#   [23 44  3]
#   [19 30 13]
#   ...
#   [36 29 21]
#   [38 31 23]
#   [36 29 23]]]
# [[38.146 39.146 38.157 ... 38.    39.    37.   ]
#  [39.146 40.146 38.157 ... 38.    38.    38.   ]
#  [38.146 39.146 37.146 ... 38.    41.    37.   ]
#  ...
#  [28.773 26.126 24.832 ... 33.409 29.409 31.409]
#  [46.047 35.269 25.126 ... 32.181 31.181 33.409]
#  [49.885 33.047 24.773 ... 30.181 32.181 30.409]]
